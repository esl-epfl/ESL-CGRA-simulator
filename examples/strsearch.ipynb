# %%
import sys
sys.path.append("../src/")
from cgra import *

kernel_name = "strsearch"
# Input data
clear_memory(kernel_name)
add_memory_region(kernel_name, 1000, [50, 123, 36464, 112, 37800, 45])
# Set load and write addrs
load_addrs = [0, 1000, 1008, 1016]
store_addrs = [0, 4, 0, 0]
version=""
memory_manager = MEMORY()
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)
# run(kernel_name, pr=["OPS", "R0", "R2", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], load_addrs=load_addrs, store_addrs=store_addrs, limit=1000)
# Out:
# [[1000, 50], [1004, 123], [1008, 36464], [1012, 112], [1016, 37800], [1020, 45]]
# [0, 1000, 1008, 1016]
# [0, 4, 0, 0]
# Instr =  0 ( 0 )
#
#
#
#
# -------
# Instr =  1 ( 1 )
#
#
#
#
# -------
# Instr =  2 ( 2 )
#
#
#
#
# -------
# Instr =  3 ( 3 )
#
#
#
#
# -------
# Instr =  4 ( 4 )
#
#
#
#
# -------
# Instr =  5 ( 5 )
#
#
#
#
# -------
# Instr =  6 ( 6 )
#
#
#
#
# -------
# Instr =  7 ( 7 )
#
#
#
#
# -------
# Instr =  8 ( 8 )
#
#
#
#
# -------
# Instr =  9 ( 9 )
#
#
#
#
# -------
# Instr =  10 ( 10 )
#
#
#
#
# -------
# Instr =  11 ( 9 )
#
#
#
#
# -------
# Instr =  12 ( 10 )
#
#
#
#
# -------
# Instr =  13 ( 9 )
#
#
#
#
# -------
# Instr =  14 ( 10 )
#
#
#
#
# -------
# Instr =  15 ( 9 )
#
#
#
#
# -------
# Instr =  16 ( 10 )
#
#
#
#
# -------
# Instr =  17 ( 9 )
#
#
#
#
# -------
# Instr =  18 ( 10 )
#
#
#
#
# -------
# Instr =  19 ( 9 )
#
#
#
#
# -------
# Instr =  20 ( 10 )
#
#
#
#
# -------
# Instr =  21 ( 9 )
#
#
#
#
# -------
# Instr =  22 ( 10 )
#
#
#
#
# -------
# Instr =  23 ( 9 )
#
#
#
#
# -------
# Instr =  24 ( 10 )
#
#
#
#
# -------
# Instr =  25 ( 9 )
#
#
#
#
# -------
# Instr =  26 ( 10 )
#
#
#
#
# -------
# Instr =  27 ( 9 )
#
#
#
#
# -------
# Instr =  28 ( 10 )
#
#
#
#
# -------
# Instr =  29 ( 9 )
#
#
#
#
# -------
# Instr =  30 ( 10 )
#
#
#
#
# -------
# Instr =  31 ( 9 )
#
#
#
#
# -------
# Instr =  32 ( 10 )
#
#
#
#
# -------
# Instr =  33 ( 9 )
#
#
#
#
# -------
# Instr =  34 ( 10 )
#
#
#
#
# -------
# Instr =  35 ( 9 )
#
#
#
#
# -------
# Instr =  36 ( 10 )
#
#
#
#
# -------
# Instr =  37 ( 9 )
#
#
#
#
# -------
# Instr =  38 ( 10 )
#
#
#
#
# -------
# Instr =  39 ( 9 )
#
#
#
#
# -------
# Instr =  40 ( 10 )
#
#
#
#
# -------
# Instr =  41 ( 9 )
#
#
#
#
# -------
# Instr =  42 ( 10 )
#
#
#
#
# -------
# Instr =  43 ( 9 )
#
#
#
#
# -------
# Instr =  44 ( 10 )
#
#
#
#
# -------
# Instr =  45 ( 9 )
#
#
#
#
# -------
# Instr =  46 ( 10 )
#
#
#
#
# -------
# Instr =  47 ( 9 )
#
#
#
#
# -------
# Instr =  48 ( 10 )
#
#
#
#
# -------
# Instr =  49 ( 9 )
#
#
#
#
# -------
# Instr =  50 ( 10 )
#
#
#
#
# -------
# Instr =  51 ( 9 )
#
#
#
#
# -------
# Instr =  52 ( 10 )
#
#
#
#
# -------
# Instr =  53 ( 9 )
#
#
#
#
# -------
# Instr =  54 ( 10 )
#
#
#
#
# -------
# Instr =  55 ( 9 )
#
#
#
#
# -------
# Instr =  56 ( 10 )
#
#
#
#
# -------
# Instr =  57 ( 9 )
#
#
#
#
# -------
# Instr =  58 ( 10 )
#
#
#
#
# -------
# Instr =  59 ( 9 )
#
#
#
#
# -------
# Instr =  60 ( 10 )
#
#
#
#
# -------
# Instr =  61 ( 9 )
#
#
#
#
# -------
# Instr =  62 ( 10 )
#
#
#
#
# -------
# Instr =  63 ( 9 )
#
#
#
#
# -------
# Instr =  64 ( 10 )
#
#
#
#
# -------
# Instr =  65 ( 9 )
#
#
#
#
# -------
# Instr =  66 ( 10 )
#
#
#
#
# -------
# Instr =  67 ( 9 )
#
#
#
#
# -------
# Instr =  68 ( 10 )
#
#
#
#
# -------
# Instr =  69 ( 9 )
#
#
#
#
# -------
# Instr =  70 ( 10 )
#
#
#
#
# -------
# Instr =  71 ( 9 )
#
#
#
#
# -------
# Instr =  72 ( 10 )
#
#
#
#
# -------
# Instr =  73 ( 9 )
#
#
#
#
# -------
# Instr =  74 ( 10 )
#
#
#
#
# -------
# Instr =  75 ( 9 )
#
#
#
#
# -------
# Instr =  76 ( 10 )
#
#
#
#
# -------
# Instr =  77 ( 9 )
#
#
#
#
# -------
# Instr =  78 ( 10 )
#
#
#
#
# -------
# Instr =  79 ( 9 )
#
#
#
#
# -------
# Instr =  80 ( 10 )
#
#
#
#
# -------
# Instr =  81 ( 9 )
#
#
#
#
# -------
# Instr =  82 ( 10 )
#
#
#
#
# -------
# Instr =  83 ( 9 )
#
#
#
#
# -------
# Instr =  84 ( 10 )
#
#
#
#
# -------
# Instr =  85 ( 9 )
#
#
#
#
# -------
# Instr =  86 ( 10 )
#
#
#
#
# -------
# Instr =  87 ( 9 )
#
#
#
#
# -------
# Instr =  88 ( 10 )
#
#
#
#
# -------
# Instr =  89 ( 9 )
#
#
#
#
# -------
# Instr =  90 ( 10 )
#
#
#
#
# -------
# Instr =  91 ( 9 )
#
#
#
#
# -------
# Instr =  92 ( 10 )
#
#
#
#
# -------
# Instr =  93 ( 11 )
#
#
#
#
# -------
# Instr =  94 ( 12 )
#
#
#
#
# -------
# Instr =  95 ( 13 )
#
#
#
#
# -------
# Instr =  96 ( 14 )
#
#
#
#
# -------
# Instr =  97 ( 15 )
#
#
#
#
# -------
# Instr =  98 ( 16 )
#
#
#
#
# -------
# Instr =  99 ( 17 )
#
#
#
#
# -------
# Instr =  100 ( 18 )
#
#
#
#
#
# Configuration time: 19 CC
# Time between end of configuration and start of first iteration: 71 CC
# Total time for all instructions: 295 CC
#
# Average power per operation:
#
# [3.14e-05, 2.70e-05, 1.79e-05, 3.44e-05]
# [2.65e-05, 2.72e-05, 2.13e-05, 2.69e-05]
# [1.79e-05, 1.79e-05, 4.32e-05, 2.73e-05]
# [1.79e-05, 3.71e-05, 3.63e-05, 2.98e-05]
#
# Power estimation for all instructions: 4.40e-04  W
#
# Total energy consumed during execution: 1.58e-09 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 99
# Number of reconfigurations:
# NOP-NOP: 490
# LWD-LWD: 6
# SADD-SADD: 2
# LWD-NOP: 5
# NOP-SADD: 466
# LWD-SADD: 1
# NOP-SMUL: 93
# LWI-NOP: 93
# BEQ-SADD: 6
# LXOR-NOP: 92
# SADD-SMUL: 91
# LWI-SSUB: 91
# BZFA-SADD: 91
# BNE-SADD: 83
# BNE-NOP: 1
# BEQ-NOP: 2
# NOP-SSUB: 1
# BZFA-SWD: 1
# EXIT-NOP: 1
#
#
# END
