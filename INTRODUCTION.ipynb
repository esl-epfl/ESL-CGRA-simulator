# %% [markdown]
# # Test a ready kernel

# %%
import sys
sys.path.append("src/")
from cgra import *

# Set the kernel name
kernel_name = "examples/convolution"
version = "_v1"
# Input data
clear_memory(kernel_name, version)
add_memory_region(kernel_name, 36464, [1, 2, 3, 4, 5, 6, 7, 8, 9], version)
add_memory_region(kernel_name, 100, [9], version)
# Set load and write addrs
load_addrs = [36464, 36464, 36464, 100]
store_addrs = [0, 0, 0, 4]
# Run the example

run(kernel_name, version=version, pr=["ROUT","OPS", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], load_addrs=load_addrs, store_addrs=store_addrs, limit=1000)
# run(kernel_name, version=version, pr=["ROUT","OPS", "ALL_LAT_INFO"], load_addrs=load_addrs, store_addrs=store_addrs)
# Out:
# [[36464, 1], [36468, 2], [36472, 3], [36476, 4], [36480, 5], [36484, 6], [36488, 7], [36492, 8], [36496, 9], [100, 9]]
# [36464, 36464, 36464, 100]
# [0, 0, 0, 4]
# Instr =  0 ( 0 )
# [   1,    1,    1,    9]    [LWD , LWD , LWD , LWD ]    [3.32e-05, 3.32e-05, 3.32e-05, 3.32e-05]
# [   2,    2,    2,    0]    [LWD , LWD , LWD , NOP ]    [3.32e-05, 3.32e-05, 3.32e-05, 1.47e-05]
# [   3,    3,    3,    0]    [LWD , LWD , LWD , NOP ]    [3.32e-05, 3.32e-05, 3.32e-05, 1.47e-05]
# [   0,    0,    0,    0]    [NOP , NOP , NOP , NOP ]    [1.47e-05, 1.47e-05, 1.47e-05, 1.47e-05]
# Power: 4.20e-04 W, Energy: 5.89e-03 J
# -------
# Instr =  1 ( 1 )
# [   2,    2,    2,    6]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [   4,    4,    4,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [   6,    6,    6,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [   0,    0,    0,    0]    [NOP , NOP , NOP , NOP ]    [1.78e-05, 1.78e-05, 1.78e-05, 1.78e-05]
# Power: 9.92e-04 W, Energy: 2.98e-03 J
# -------
# Instr =  2 ( 2 )
# [   1,    1,    1,    9]    [SADD, SADD, SADD, BEQ ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   2,    2,    2,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [  10,   10,   10,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [   2,    2,    2,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# Power: 6.74e-04 W, Energy: 6.83e-04 J
# -------
# Instr =  3 ( 3 )
# [   4,    4,    4,    9]    [LWD , LWD , LWD , NOP ]    [2.48e-05, 2.48e-05, 2.48e-05, 1.60e-05]
# [   1,    1,    1,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.60e-05]
# [   2,    2,    2,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.60e-05]
# [  12,   12,   12,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.60e-05]
# Power: 5.55e-04 W, Energy: 2.84e-03 J
# -------
# Instr =  4 ( 4 )
# [   8,    8,    8,    5]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [   2,    2,    2,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [   4,    4,    4,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  24,   12,   12,   12]    [SADD, NOP , NOP , SADD]    [3.61e-05, 1.78e-05, 1.78e-05, 3.61e-05]
# Power: 1.03e-03 W, Energy: 3.15e-03 J
# -------
# Instr =  5 ( 5 )
# [   4,    4,    4,    9]    [SADD, SADD, SADD, BEQ ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   1,    1,    1,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [   6,    6,    6,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [   8,    8,    8,   36]    [SADD, SADD, SADD, SADD]    [4.89e-05, 4.89e-05, 4.89e-05, 4.89e-05]
# Power: 6.99e-04 W, Energy: 7.27e-04 J
# -------
# Instr =  6 ( 6 )
# [   5,    5,    5,    9]    [LWD , LWD , LWD , NOP ]    [3.34e-05, 3.34e-05, 3.34e-05, 1.54e-05]
# [   4,    4,    4,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [   1,    1,    1,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [  14,   14,   14,   36]    [SADD, SADD, SADD, SWD ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.80e-05]
# Power: 5.81e-04 W, Energy: 4.30e-03 J
# -------
# Instr =  7 ( 7 )
# [  10,   10,   10,    4]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [   8,    8,    8,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [   2,    2,    2,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  28,   14,   14,   14]    [SADD, NOP , NOP , SADD]    [3.61e-05, 1.78e-05, 1.78e-05, 3.61e-05]
# Power: 1.03e-03 W, Energy: 3.20e-03 J
# -------
# Instr =  8 ( 8 )
# [   5,    5,    5,    6]    [SADD, SADD, SADD, BNE ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   4,    4,    4,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [  10,   10,   10,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [  10,   10,   10,   42]    [SADD, SADD, SADD, SADD]    [4.89e-05, 4.89e-05, 4.89e-05, 4.89e-05]
# Power: 6.99e-04 W, Energy: 7.45e-04 J
# -------
# Instr =  9 ( 6 )
# [   6,    6,    6,    6]    [LWD , LWD , LWD , NOP ]    [3.34e-05, 3.34e-05, 3.34e-05, 1.54e-05]
# [   5,    5,    5,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [   4,    4,    4,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [  20,   20,   20,   42]    [SADD, SADD, SADD, SWD ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.80e-05]
# Power: 5.81e-04 W, Energy: 4.43e-03 J
# -------
# Instr =  10 ( 7 )
# [  12,   12,   12,    3]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [  10,   10,   10,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [   8,    8,    8,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  40,   20,   20,   20]    [SADD, NOP , NOP , SADD]    [3.61e-05, 1.78e-05, 1.78e-05, 3.61e-05]
# Power: 1.03e-03 W, Energy: 3.26e-03 J
# -------
# Instr =  11 ( 8 )
# [   6,    6,    6,    6]    [SADD, SADD, SADD, BNE ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   5,    5,    5,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [  18,   18,   18,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [  12,   12,   12,   60]    [SADD, SADD, SADD, SADD]    [4.89e-05, 4.89e-05, 4.89e-05, 4.89e-05]
# Power: 6.99e-04 W, Energy: 7.64e-04 J
# -------
# Instr =  12 ( 6 )
# [   7,    7,    7,    6]    [LWD , LWD , LWD , NOP ]    [3.34e-05, 3.34e-05, 3.34e-05, 1.54e-05]
# [   6,    6,    6,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [   5,    5,    5,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [  30,   30,   30,   60]    [SADD, SADD, SADD, SWD ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.80e-05]
# Power: 5.81e-04 W, Energy: 4.56e-03 J
# -------
# Instr =  13 ( 7 )
# [  14,   14,   14,    2]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [  12,   12,   12,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  10,   10,   10,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  60,   30,   30,   30]    [SADD, NOP , NOP , SADD]    [3.61e-05, 1.78e-05, 1.78e-05, 3.61e-05]
# Power: 1.03e-03 W, Energy: 3.31e-03 J
# -------
# Instr =  14 ( 8 )
# [   7,    7,    7,    6]    [SADD, SADD, SADD, BNE ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   6,    6,    6,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [  22,   22,   22,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [  14,   14,   14,   90]    [SADD, SADD, SADD, SADD]    [4.89e-05, 4.89e-05, 4.89e-05, 4.89e-05]
# Power: 6.99e-04 W, Energy: 7.83e-04 J
# -------
# Instr =  15 ( 6 )
# [   8,    8,    8,    6]    [LWD , LWD , LWD , NOP ]    [3.34e-05, 3.34e-05, 3.34e-05, 1.54e-05]
# [   7,    7,    7,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [   6,    6,    6,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [  36,   36,   36,   90]    [SADD, SADD, SADD, SWD ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.80e-05]
# Power: 5.81e-04 W, Energy: 4.69e-03 J
# -------
# Instr =  16 ( 7 )
# [  16,   16,   16,    1]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [  14,   14,   14,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  12,   12,   12,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  72,   36,   36,   36]    [SADD, NOP , NOP , SADD]    [3.61e-05, 1.78e-05, 1.78e-05, 3.61e-05]
# Power: 1.03e-03 W, Energy: 3.37e-03 J
# -------
# Instr =  17 ( 8 )
# [   8,    8,    8,    6]    [SADD, SADD, SADD, BNE ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   7,    7,    7,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [  26,   26,   26,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [  16,   16,   16,  108]    [SADD, SADD, SADD, SADD]    [4.89e-05, 4.89e-05, 4.89e-05, 4.89e-05]
# Power: 6.99e-04 W, Energy: 8.02e-04 J
# -------
# Instr =  18 ( 6 )
# [   9,    9,    9,    6]    [LWD , LWD , LWD , NOP ]    [3.34e-05, 3.34e-05, 3.34e-05, 1.54e-05]
# [   8,    8,    8,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [   7,    7,    7,    0]    [SADD, SADD, SADD, NOP ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.54e-05]
# [  42,   42,   42,  108]    [SADD, SADD, SADD, SWD ]    [4.63e-05, 4.63e-05, 4.63e-05, 1.80e-05]
# Power: 5.81e-04 W, Energy: 4.82e-03 J
# -------
# Instr =  19 ( 7 )
# [  18,   18,   18,    0]    [SMUL, SMUL, SMUL, SSUB]    [9.28e-05, 9.28e-05, 9.28e-05, 5.02e-05]
# [  16,   16,   16,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  14,   14,   14,    0]    [SMUL, SMUL, SMUL, NOP ]    [9.28e-05, 9.28e-05, 9.28e-05, 1.78e-05]
# [  84,   42,   42,   42]    [SADD, NOP , NOP , SADD]    [3.61e-05, 1.78e-05, 1.78e-05, 3.61e-05]
# Power: 1.03e-03 W, Energy: 3.43e-03 J
# -------
# Instr =  20 ( 8 )
# [   9,    9,    9,    6]    [SADD, SADD, SADD, BNE ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.48e-05]
# [   8,    8,    8,    0]    [SADD, SADD, SADD, NOP ]    [4.72e-05, 4.72e-05, 4.72e-05, 2.43e-05]
# [  30,   30,   30,    0]    [SADD, SADD, SADD, NOP ]    [4.89e-05, 4.89e-05, 4.89e-05, 2.43e-05]
# [  18,   18,   18,  126]    [SADD, SADD, SADD, SADD]    [4.89e-05, 4.89e-05, 4.89e-05, 4.89e-05]
# Power: 6.99e-04 W, Energy: 8.21e-04 J
# -------
# Instr =  21 ( 9 )
# [   9,    9,    9,    6]    [NOP , NOP , NOP , NOP ]    [1.78e-05, 1.78e-05, 1.78e-05, 1.78e-05]
# [   8,    8,    8,    0]    [NOP , NOP , NOP , NOP ]    [1.78e-05, 1.78e-05, 1.78e-05, 1.78e-05]
# [  30,   30,   30,    0]    [NOP , NOP , NOP , NOP ]    [1.78e-05, 1.78e-05, 1.78e-05, 1.78e-05]
# [  48,   48,   48,  126]    [SADD, SADD, SADD, SWD ]    [3.61e-05, 3.61e-05, 3.61e-05, 1.75e-05]
# Power: 3.39e-04 W, Energy: 1.40e-03 J
# -------
# Instr =  22 ( 10 )
# [   9,    9,    9,    6]    [NOP , NOP , NOP , NOP ]    [2.43e-05, 2.43e-05, 2.43e-05, 2.43e-05]
# [   8,    8,    8,    0]    [NOP , NOP , NOP , NOP ]    [2.43e-05, 2.43e-05, 2.43e-05, 2.43e-05]
# [  30,   30,   30,    0]    [NOP , NOP , NOP , NOP ]    [2.43e-05, 2.43e-05, 2.43e-05, 2.43e-05]
# [  96,   48,   48,   48]    [SADD, NOP , NOP , SADD]    [4.89e-05, 2.43e-05, 2.43e-05, 4.89e-05]
# Power: 4.38e-04 W, Energy: 5.66e-04 J
# -------
# Instr =  23 ( 11 )
# [   9,    9,    9,    6]    [NOP , NOP , NOP , NOP ]    [2.43e-05, 2.43e-05, 2.43e-05, 2.43e-05]
# [   8,    8,    8,    0]    [NOP , NOP , NOP , NOP ]    [2.43e-05, 2.43e-05, 2.43e-05, 2.43e-05]
# [  30,   30,   30,    0]    [NOP , NOP , NOP , NOP ]    [2.43e-05, 2.43e-05, 2.43e-05, 2.43e-05]
# [  96,   48,   48,  144]    [NOP , NOP , NOP , SADD]    [2.43e-05, 2.43e-05, 2.43e-05, 4.89e-05]
# Power: 4.13e-04 W, Energy: 5.43e-04 J
# -------
# Instr =  24 ( 12 )
# [   9,    9,    9,    6]    [EXIT, NOP , NOP , NOP ]    [1.72e-05, 1.65e-05, 1.65e-05, 1.65e-05]
# [   8,    8,    8,    0]    [NOP , NOP , NOP , NOP ]    [1.65e-05, 1.65e-05, 1.65e-05, 1.65e-05]
# [  30,   30,   30,    0]    [NOP , NOP , NOP , NOP ]    [1.65e-05, 1.65e-05, 1.65e-05, 1.65e-05]
# [  96,   48,   48,  144]    [NOP , NOP , NOP , SWD ]    [1.65e-05, 1.65e-05, 1.65e-05, 1.53e-05]
# Power: 2.63e-04 W, Energy: 1.58e-03 J
#
# Longest instructions per cycle:
#
# Cycle    Instruction               Latency (CC)
# 1  (0)    MEM (LWD R0)              14.0
# 2  (1)    SMUL ROUT  R0  2          3
# 3  (2)    SADD ROUT  R0  0          1
# 4  (3)    MEM (LWD R0)              5.0
# 5  (4)    SMUL ROUT  R0  2          3
# 6  (5)    SADD ROUT  R0  0          1
# 7  (6)    MEM (LWD R0)              7.0
# 8  (7)    SMUL ROUT  R0  2          3
# 9  (5)    SADD ROUT  R0  0          1
# 10 (6)    MEM (LWD R0)              7.0
# 11 (7)    SMUL ROUT  R0  2          3
# 12 (5)    SADD ROUT  R0  0          1
# 13 (6)    MEM (LWD R0)              7.0
# 14 (7)    SMUL ROUT  R0  2          3
# 15 (5)    SADD ROUT  R0  0          1
# 16 (6)    MEM (LWD R0)              7.0
# 17 (7)    SMUL ROUT  R0  2          3
# 18 (5)    SADD ROUT  R0  0          1
# 19 (6)    MEM (LWD R0)              7.0
# 20 (7)    SMUL ROUT  R0  2          3
# 21 (8)    SADD ROUT  R0  0          1
# 22 (9)    MEM (SWD ROUT)            3.0
# 23 (10)   NOP                       1
# 24 (11)   NOP                       1
# 25 (12)   MEM (EXIT)                4.0
#
# Configuration time: 13 CC
# Time between end of configuration and start of first iteration: 53 CC
# Total time for all instructions: 91.0 CC
#
# Average power per operation:
#
# [5.88e-05, 5.88e-05, 5.88e-05, 3.17e-05]
# [6.33e-05, 6.33e-05, 6.33e-05, 1.88e-05]
# [6.34e-05, 6.34e-05, 6.34e-05, 1.88e-05]
# [4.04e-05, 4.02e-05, 4.02e-05, 2.52e-05]
#
# Power estimation for all instructions: 7.72e-04  W
#
# Total energy consumed during execution: 6.83e-10 J
#
# Clock period used: 1.25e-08 s
#
#
# END

# %% [markdown]
# # Create a new kernel

# %%
from sat_to_csv import *
from kernels import *

# Kernels will be located in a folder with the kernel's name
kernel_name = "examples/strsearch"

# Create a new folder (if it does not exist already) and add the minimum necessary files to run it
kernel_new(kernel_name)

# If you have a assembly in the SAT-MapIt format, you can convert it to a csv
convert( kernel_name+"/out.sat", kernel_name+"/instructions.csv" )

# To test this kernel we will fill the memory with two random arrays
# Note that the addresses in memory (36464 and 37800) correspond to inputs in the inputs.csv file)
clear_memory(kernel_name)
add_memory_region(kernel_name, 1000, [50, 123, 36464, 112, 37800, 45])
# Out:
# Kernel examples/strsearch already exists!

# %%
import cgra
# Set load and write addrs
load_addrs = [0, 1000, 1008, 1016]
store_addrs = [0, 4, 0, 0]
cgra.run( kernel_name, pr=["ROUT", "R0","INST"], limit=120, load_addrs=load_addrs, store_addrs=store_addrs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 load_addrs = [0, 1000, 1008, 1016]
#       4 store_addrs = [0, 4, 0, 0]
# ----> 5 cgra.run( kernel_name, pr=["ROUT", "R0","INST"], limit=120, load_addrs=load_addrs, store_addrs=store_addrs)
#
# File c:\Users\Maxime\OneDrive\Documents\GitHub\ESL-CGRA-simulator\src\cgra.py:445, in run(kernel, version, pr, limit, load_addrs, store_addrs, memory_manager)
#     442             return None
#     444 # Run the kernel
# --> 445 cgra = CGRA(ker, mem, load_addrs, store_addrs, memory_manager)
#     446 mem = cgra.run(pr, limit)
#     448 # Store the output sorted
#
# File c:\Users\Maxime\OneDrive\Documents\GitHub\ESL-CGRA-simulator\src\cgra.py:85, in CGRA.__init__(self, kernel, memory, read_addrs, write_addrs, memory_manager)
#      83         list.append( PE( self, r, c) )
#      84     self.cells.append(list)
# ---> 85 self.instrs     = ker_parse( kernel )
#      86 self.memory     = memory
#      87 self.instr2exec = 0
#
# File c:\Users\Maxime\OneDrive\Documents\GitHub\ESL-CGRA-simulator\src\cgra.py:33, in ker_parse(data)
#      31 def ker_parse( data ):
#      32     instrs = int(len(data)/( INSTR_SIZE  )) # Always have a CSV with as many csv-columns as CGA-columns. Each instruction starts with the instruction timestamp i nthe first column. The next instruction must be immediately after the last row of this instruction.
# ---> 33     return [ INSTR( data[r_i*INSTR_SIZE:(r_i+1)*INSTR_SIZE][0:] ) for r_i in range(instrs) ]
#
# File c:\Users\Maxime\OneDrive\Documents\GitHub\ESL-CGRA-simulator\src\cgra.py:29, in INSTR.__init__(self, matrix)
#      27 def __init__( self,matrix):
#      28     self.time = matrix[0][0]                        # ToDo: Fix how we assign this length
# ---> 29     self.ops = [[ matrix[r+1][c] for c in range(N_COLS)] for r in range(N_ROWS)]
#
# IndexError: list index out of range

# %% [markdown]
# # Your turn to play around

# %%
import sys
sys.path.append("src/")
from cgra import *


# Set the kernel name
# 

# kernel_name = "examples/reconfig"
# version = ""
# kernel_name = "test_kernel"
# version = "_v1xTEST"
# kernel_name = "passive_kernels"
# version = "_v1xSADD_LWD"

# kernel_name = "examples/test"
# version = "_v3"

# kernel_name = "examples/power_tests"
# version = "_v1xLONG"
# clear_memory(kernel_name, version)

# gsm
# kernel_name = "examples/gsm"
# version = "_v1"
# clear_memory(kernel_name, version)
# add_memory_region(kernel_name, 100, [22698, 11480, -32658, -21981, -26949, -17398, -23942, 32423, -11483, 17581, 13842, -16291, 9355, -13496, 27455, 26106, 30664, -16369,
# 16471, -30316, -494, 32688, -11249, 967, 10429, 19344, 21117, -24938, -26203, -31221, 32568, 30046, 10410, -10212, -17320, -827, -28713, -27820, 3709, 8141], version)
# add_memory_region(kernel_name, 36464, [32767, -32768], version)
# load_addrs = [92, 100,108, 36464]
# store_addrs = [56, 68, 80, 92]


# add_memory_region(kernel_name, 8, [8, 1, 2], version)
# add_memory_region(kernel_name, 20, [8, 3, 4], version)
# add_memory_region(kernel_name, 32, [8, 5, 6], version)
# add_memory_region(kernel_name, 44, [8, 7, 8], version)
# Set load and write addrs
# load_addrs = [8, 20,32, 44]
# # store_addrs = [56, 68, 80, 92]
# store_addrs = [80, 92, 104, 116]
# Run the example

# reversebits
# kernel_name = "examples/reversebits"
# version = ""
# add_memory_region(kernel_name, 92, [-957294422, 32], version)
# load_addrs = [92, 100,108, 112]
# store_addrs = [128, 132, 136, 140]


# sha
kernel_name = "examples/sha"
version = ""

add_memory_region(kernel_name, 100, [22698, 11480, -32658, -21981, -26949, -17398, -23942, 32423, -11483, 17581, 13842, -16291, 9355, -13496, 27455, 26106, 30664, -16369,
16471, -30316, -494, 32688, -11249, 967, 10429, 19344, 21117, -24938, -26203, -31221, 32568, 30046, 10410, -10212, -17320, -827, -28713, -27820, 3709, 8141], version)
add_memory_region(kernel_name, 36464, [32767, -32768], version)
load_addrs = [100, 420,720, 1060]
store_addrs = [128, 132, 136, 140]

# sha2
# kernel_name = "examples/sha2"
# version = ""
# clear_memory(kernel_name, version)
# add_memory_region(kernel_name, 100, [22698, 11480, -32658, -21981, -26949, -17398, -23942, 32423, -11483, 17581, 13842, -16291, 9355, -13496, 27455, 26106, 30664, -16369,
# 16471, -30316, -494, 32688, -11249, 967, 10429, 19344, 21117, -24938, -26203, -31221, 32568, 30046, 10410, -10212, -17320, -827, -28713, -27820, 3709, 8141], version)
# add_memory_region(kernel_name, 36464, [1518500249], version)
# load_addrs = [100, 36464,36464, 36464]
# store_addrs = [128, 132, 136, 140]
memory_manager = MEMORY()
# run(kernel_name, version=version, pr=["OPS", "R0", "R2", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], load_addrs=load_addrs, store_addrs=store_addrs, limit=1000)
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)

# run(kernel_name, version=version, pr=["OPS", "R0", "R2", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], limit=1000)

# shutil.copy2(source_path, destination_path)

# 2.40E-05
# Out:
# [[100, -957294422], [104, 227257560], [108, 922943598], [112, 138816035], [116, -1549658437], [120, 1074543626], [124, -745790854], [128, 1171127975], [132, 1698190117], [136, 949732525], [140, 1838855698], [144, -2120007587], [148, 1968284811], [152, 1969965896], [156, -211162305], [160, -896145926], [164, 803272648], [168, -606715889], [172, 1598472279], [176, 1657932180], [180, -478249454], [184, 1432682416], [188, -194358257], [192, 996639687], [196, -347100995], [200, -1719481456], [204, -1311124867], [208, 1894588054], [212, 857676197], [216, 1409549835], [220, 520552248], [224, 1884353886], [228, 1680255146], [232, -885106660], [236, 1522023512], [240, -1930855227], [244, 1803358167], [248, 339809108], [252, 887131773], [256, 1727176653], [260, 482173232], [264, -1421112504], [268, 1286026061], [272, -1307989181], [276, 1895715258], [280, 1338680588], [284, -912627001], [288, 1636632062], [292, -1407658004], [296, -1039409052], [300, 492052332], [304, 39933767], [308, 1285117336], [312, -370174521], [316, -2023880602], [320, -683495022], [324, 826310929], [328, 144317116], [332, -1827808198], [336, 89831677], [340, 905456571], [344, 715836199], [348, 2048387088], [352, -675239002], [356, -1642211689], [360, 1814180786], [364, -457954608], [368, -1005132791], [372, -1982283728], [376, 1094103495], [380, 952282511], [384, -307302953], [388, -1347032308], [392, -840462257], [396, -1177340937], [400, 99424892], [404, 1069810423], [408, -1740344523], [412, -712874167], [416, 1354714353], [420, -957294422], [424, 227257560], [428, 922943598], [432, 138816035], [436, -1549658437], [440, 1074543626], [444, -745790854], [448, 1171127975], [452, 1698190117], [456, 949732525], [460, 1838855698], [464, -2120007587], [468, 1968284811], [472, 1969965896], [476, -211162305], [480, -896145926], [484, 803272648], [488, -606715889], [492, 1598472279], [496, 1657932180], [500, -478249454], [504, 1432682416], [508, -194358257], [512, 996639687], [516, -347100995], [520, -1719481456], [524, -1311124867], [528, 1894588054], [532, 857676197], [536, 1409549835], [540, 520552248], [544, 1884353886], [548, 1680255146], [552, -885106660], [556, 1522023512], [560, -1930855227], [564, 1803358167], [568, 339809108], [572, 887131773], [576, 1727176653], [580, 482173232], [584, -1421112504], [588, 1286026061], [592, -1307989181], [596, 1895715258], [600, 1338680588], [604, -912627001], [608, 1636632062], [612, -1407658004], [616, -1039409052], [620, 492052332], [624, 39933767], [628, 1285117336], [632, -370174521], [636, -2023880602], [640, -683495022], [644, 826310929], [648, 144317116], [652, -1827808198], [656, 89831677], [660, 905456571], [664, 715836199], [668, 2048387088], [672, -675239002], [676, -1642211689], [680, 1814180786], [684, -457954608], [688, -1005132791], [692, -1982283728], [696, 1094103495], [700, 952282511], [704, -307302953], [708, -1347032308], [712, -840462257], [716, -1177340937], [720, 99424892], [724, 1069810423], [728, -1740344523], [732, -712874167], [736, 1354714353], [740, -957294422], [744, 227257560], [748, 922943598], [752, 138816035], [756, -1549658437], [760, 1074543626], [764, -745790854], [768, 1171127975], [772, 1698190117], [776, 949732525], [780, 1838855698], [784, -2120007587], [788, 1968284811], [792, 1969965896], [796, -211162305], [800, -896145926], [804, 803272648], [808, -606715889], [812, 1598472279], [816, 1657932180], [820, -478249454], [824, 1432682416], [828, -194358257], [832, 996639687], [836, -347100995], [840, -1719481456], [844, -1311124867], [848, 1894588054], [852, 857676197], [856, 1409549835], [860, 520552248], [864, 1884353886], [868, 1680255146], [872, -885106660], [876, 1522023512], [880, -1930855227], [884, 1803358167], [888, 339809108], [892, 887131773], [896, 1727176653], [900, 482173232], [904, -1421112504], [908, 1286026061], [912, -1307989181], [916, 1895715258], [920, 1338680588], [924, -912627001], [928, 1636632062], [932, -1407658004], [936, -1039409052], [940, 492052332], [944, ...
# [100, 420, 720, 1060]
# [128, 132, 136, 140]
#
# Configuration time: 18 CC
# Time between end of configuration and start of first iteration: 68 CC
# Total time for all instructions: 728.0 CC
#
# Average power per operation:
#
#
# Power estimation for all instructions: 6.89e-04  W
#
# Total energy consumed during execution: 4.07e-09 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 325
# Number of missing reconfigurations:
# LWD-LWD: 5
# LWD-NOP: 4
# SMUL-SMUL: 64
# BEQ-NOP: 126
# BEQ-LWI: 63
# LWI-NOP: 257
# LWI-LXOR: 64
# LWI-LWI: 64
# BEQ-LXOR: 63
# SMUL-SWI: 63
# SADD-SWI: 63
# NOP-SWI: 2
# EXIT-NOP: 1
#
#
# END

# %%
import sys
sys.path.append("src/")
from cgra import *
# sha
kernel_name = "examples/sha"
version = ""

add_memory_region(kernel_name, 100, [22698, 11480, -32658, -21981, -26949, -17398, -23942, 32423, -11483, 17581, 13842, -16291, 9355, -13496, 27455, 26106, 30664, -16369,
16471, -30316, -494, 32688, -11249, 967, 10429, 19344, 21117, -24938, -26203, -31221, 32568, 30046, 10410, -10212, -17320, -827, -28713, -27820, 3709, 8141], version)
add_memory_region(kernel_name, 36464, [32767, -32768], version)
load_addrs = [100, 420,720, 1060]
store_addrs = [128, 132, 136, 140]
memory_manager = MEMORY()
# run(kernel_name, version=version, pr=["OPS", "R0", "R2", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], load_addrs=load_addrs, store_addrs=store_addrs, limit=1000)
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)
# Out:
# [[100, -957294422], [104, 227257560], [108, 922943598], [112, 138816035], [116, -1549658437], [120, 1074543626], [124, -745790854], [128, 1171127975], [132, 1698190117], [136, 949732525], [140, 1838855698], [144, -2120007587], [148, 1968284811], [152, 1969965896], [156, -211162305], [160, -896145926], [164, 803272648], [168, -606715889], [172, 1598472279], [176, 1657932180], [180, -478249454], [184, 1432682416], [188, -194358257], [192, 996639687], [196, -347100995], [200, -1719481456], [204, -1311124867], [208, 1894588054], [212, 857676197], [216, 1409549835], [220, 520552248], [224, 1884353886], [228, 1680255146], [232, -885106660], [236, 1522023512], [240, -1930855227], [244, 1803358167], [248, 339809108], [252, 887131773], [256, 1727176653], [260, 482173232], [264, -1421112504], [268, 1286026061], [272, -1307989181], [276, 1895715258], [280, 1338680588], [284, -912627001], [288, 1636632062], [292, -1407658004], [296, -1039409052], [300, 492052332], [304, 39933767], [308, 1285117336], [312, -370174521], [316, -2023880602], [320, -683495022], [324, 826310929], [328, 144317116], [332, -1827808198], [336, 89831677], [340, 905456571], [344, 715836199], [348, 2048387088], [352, -675239002], [356, -1642211689], [360, 1814180786], [364, -457954608], [368, -1005132791], [372, -1982283728], [376, 1094103495], [380, 952282511], [384, -307302953], [388, -1347032308], [392, -840462257], [396, -1177340937], [400, 99424892], [404, 1069810423], [408, -1740344523], [412, -712874167], [416, 1354714353], [420, -957294422], [424, 227257560], [428, 922943598], [432, 138816035], [436, -1549658437], [440, 1074543626], [444, -745790854], [448, 1171127975], [452, 1698190117], [456, 949732525], [460, 1838855698], [464, -2120007587], [468, 1968284811], [472, 1969965896], [476, -211162305], [480, -896145926], [484, 803272648], [488, -606715889], [492, 1598472279], [496, 1657932180], [500, -478249454], [504, 1432682416], [508, -194358257], [512, 996639687], [516, -347100995], [520, -1719481456], [524, -1311124867], [528, 1894588054], [532, 857676197], [536, 1409549835], [540, 520552248], [544, 1884353886], [548, 1680255146], [552, -885106660], [556, 1522023512], [560, -1930855227], [564, 1803358167], [568, 339809108], [572, 887131773], [576, 1727176653], [580, 482173232], [584, -1421112504], [588, 1286026061], [592, -1307989181], [596, 1895715258], [600, 1338680588], [604, -912627001], [608, 1636632062], [612, -1407658004], [616, -1039409052], [620, 492052332], [624, 39933767], [628, 1285117336], [632, -370174521], [636, -2023880602], [640, -683495022], [644, 826310929], [648, 144317116], [652, -1827808198], [656, 89831677], [660, 905456571], [664, 715836199], [668, 2048387088], [672, -675239002], [676, -1642211689], [680, 1814180786], [684, -457954608], [688, -1005132791], [692, -1982283728], [696, 1094103495], [700, 952282511], [704, -307302953], [708, -1347032308], [712, -840462257], [716, -1177340937], [720, 99424892], [724, 1069810423], [728, -1740344523], [732, -712874167], [736, 1354714353], [740, -957294422], [744, 227257560], [748, 922943598], [752, 138816035], [756, -1549658437], [760, 1074543626], [764, -745790854], [768, 1171127975], [772, 1698190117], [776, 949732525], [780, 1838855698], [784, -2120007587], [788, 1968284811], [792, 1969965896], [796, -211162305], [800, -896145926], [804, 803272648], [808, -606715889], [812, 1598472279], [816, 1657932180], [820, -478249454], [824, 1432682416], [828, -194358257], [832, 996639687], [836, -347100995], [840, -1719481456], [844, -1311124867], [848, 1894588054], [852, 857676197], [856, 1409549835], [860, 520552248], [864, 1884353886], [868, 1680255146], [872, -885106660], [876, 1522023512], [880, -1930855227], [884, 1803358167], [888, 339809108], [892, 887131773], [896, 1727176653], [900, 482173232], [904, -1421112504], [908, 1286026061], [912, -1307989181], [916, 1895715258], [920, 1338680588], [924, -912627001], [928, 1636632062], [932, -1407658004], [936, -1039409052], [940, 492052332], [944, ...
# [100, 420, 720, 1060]
# [128, 132, 136, 140]
# Instr =  0 ( 0 )
#
#
#
#
# -------
# Instr =  1 ( 1 )
#
#
#
#
# -------
# Instr =  2 ( 2 )
#
#
#
#
# -------
# Instr =  3 ( 3 )
#
#
#
#
# -------
# Instr =  4 ( 4 )
#
#
#
#
# -------
# Instr =  5 ( 5 )
#
#
#
#
# -------
# Instr =  6 ( 6 )
#
#
#
#
# -------
# Instr =  7 ( 7 )
#
#
#
#
# -------
# Instr =  8 ( 8 )
#
#
#
#
# -------
# Instr =  9 ( 9 )
#
#
#
#
# -------
# Instr =  10 ( 10 )
#
#
#
#
# -------
# Instr =  11 ( 8 )
#
#
#
#
# -------
# Instr =  12 ( 9 )
#
#
#
#
# -------
# Instr =  13 ( 10 )
#
#
#
#
# -------
# Instr =  14 ( 8 )
#
#
#
#
# -------
# Instr =  15 ( 9 )
#
#
#
#
# -------
# Instr =  16 ( 10 )
#
#
#
#
# -------
# Instr =  17 ( 8 )
#
#
#
#
# -------
# Instr =  18 ( 9 )
#
#
#
#
# -------
# Instr =  19 ( 10 )
#
#
#
#
# -------
# Instr =  20 ( 8 )
#
#
#
#
# -------
# Instr =  21 ( 9 )
#
#
#
#
# -------
# Instr =  22 ( 10 )
#
#
#
#
# -------
# Instr =  23 ( 8 )
#
#
#
#
# -------
# Instr =  24 ( 9 )
#
#
#
#
# -------
# Instr =  25 ( 10 )
#
#
#
#
# -------
# Instr =  26 ( 8 )
#
#
#
#
# -------
# Instr =  27 ( 9 )
#
#
#
#
# -------
# Instr =  28 ( 10 )
#
#
#
#
# -------
# Instr =  29 ( 8 )
#
#
#
#
# -------
# Instr =  30 ( 9 )
#
#
#
#
# -------
# Instr =  31 ( 10 )
#
#
#
#
# -------
# Instr =  32 ( 8 )
#
#
#
#
# -------
# Instr =  33 ( 9 )
#
#
#
#
# -------
# Instr =  34 ( 10 )
#
#
#
#
# -------
# Instr =  35 ( 8 )
#
#
#
#
# -------
# Instr =  36 ( 9 )
#
#
#
#
# -------
# Instr =  37 ( 10 )
#
#
#
#
# -------
# Instr =  38 ( 8 )
#
#
#
#
# -------
# Instr =  39 ( 9 )
#
#
#
#
# -------
# Instr =  40 ( 10 )
#
#
#
#
# -------
# Instr =  41 ( 8 )
#
#
#
#
# -------
# Instr =  42 ( 9 )
#
#
#
#
# -------
# Instr =  43 ( 10 )
#
#
#
#
# -------
# Instr =  44 ( 8 )
#
#
#
#
# -------
# Instr =  45 ( 9 )
#
#
#
#
# -------
# Instr =  46 ( 10 )
#
#
#
#
# -------
# Instr =  47 ( 8 )
#
#
#
#
# -------
# Instr =  48 ( 9 )
#
#
#
#
# -------
# Instr =  49 ( 10 )
#
#
#
#
# -------
# Instr =  50 ( 8 )
#
#
#
#
# -------
# Instr =  51 ( 9 )
#
#
#
#
# -------
# Instr =  52 ( 10 )
#
#
#
#
# -------
# Instr =  53 ( 8 )
#
#
#
#
# -------
# Instr =  54 ( 9 )
#
#
#
#
# -------
# Instr =  55 ( 10 )
#
#
#
#
# -------
# Instr =  56 ( 8 )
#
#
#
#
# -------
# Instr =  57 ( 9 )
#
#
#
#
# -------
# Instr =  58 ( 10 )
#
#
#
#
# -------
# Instr =  59 ( 8 )
#
#
#
#
# -------
# Instr =  60 ( 9 )
#
#
#
#
# -------
# Instr =  61 ( 10 )
#
#
#
#
# -------
# Instr =  62 ( 8 )
#
#
#
#
# -------
# Instr =  63 ( 9 )
#
#
#
#
# -------
# Instr =  64 ( 10 )
#
#
#
#
# -------
# Instr =  65 ( 8 )
#
#
#
#
# -------
# Instr =  66 ( 9 )
#
#
#
#
# -------
# Instr =  67 ( 10 )
#
#
#
#
# -------
# Instr =  68 ( 8 )
#
#
#
#
# -------
# Instr =  69 ( 9 )
#
#
#
#
# -------
# Instr =  70 ( 10 )
#
#
#
#
# -------
# Instr =  71 ( 8 )
#
#
#
#
# -------
# Instr =  72 ( 9 )
#
#
#
#
# -------
# Instr =  73 ( 10 )
#
#
#
#
# -------
# Instr =  74 ( 8 )
#
#
#
#
# -------
# Instr =  75 ( 9 )
#
#
#
#
# -------
# Instr =  76 ( 10 )
#
#
#
#
# -------
# Instr =  77 ( 8 )
#
#
#
#
# -------
# Instr =  78 ( 9 )
#
#
#
#
# -------
# Instr =  79 ( 10 )
#
#
#
#
# -------
# Instr =  80 ( 8 )
#
#
#
#
# -------
# Instr =  81 ( 9 )
#
#
#
#
# -------
# Instr =  82 ( 10 )
#
#
#
#
# -------
# Instr =  83 ( 8 )
#
#
#
#
# -------
# Instr =  84 ( 9 )
#
#
#
#
# -------
# Instr =  85 ( 10 )
#
#
#
#
# -------
# Instr =  86 ( 8 )
#
#
#
#
# -------
# Instr =  87 ( 9 )
#
#
#
#
# -------
# Instr =  88 ( 10 )
#
#
#
#
# -------
# Instr =  89 ( 8 )
#
#
#
#
# -------
# Instr =  90 ( 9 )
#
#
#
#
# -------
# Instr =  91 ( 10 )
#
#
#
#
# -------
# Instr =  92 ( 8 )
#
#
#
#
# -------
# Instr =  93 ( 9 )
#
#
#
#
# -------
# Instr =  94 ( 10 )
#
#
#
#
# -------
# Instr =  95 ( 8 )
#
#
#
#
# -------
# Instr =  96 ( 9 )
#
#
#
#
# -------
# Instr =  97 ( 10 )
#
#
#
#
# -------
# Instr =  98 ( 8 )
#
#
#
#
# -------
# Instr =  99 ( 9 )
#
#
#
#
# -------
# Instr =  100 ( 10 )
#
#
#
#
# -------
# Instr =  101 ( 8 )
#
#
#
#
# -------
# Instr =  102 ( 9 )
#
#
#
#
# -------
# Instr =  103 ( 10 )
#
#
#
#
# -------
# Instr =  104 ( 8 )
#
#
#
#
# -------
# Instr =  105 ( 9 )
#
#
#
#
# -------
# Instr =  106 ( 10 )
#
#
#
#
# -------
# Instr =  107 ( 8 )
#
#
#
#
# -------
# Instr =  108 ( 9 )
#
#
#
#
# -------
# Instr =  109 ( 10 )
#
#
#
#
# -------
# Instr =  110 ( 8 )
#
#
#
#
# -------
# Instr =  111 ( 9 )
#
#
#
#
# -------
# Instr =  112 ( 10 )
#
#
#
#
# -------
# Instr =  113 ( 8 )
#
#
#
#
# -------
# Instr =  114 ( 9 )
#
#
#
#
# -------
# Instr =  115 ( 10 )
#
#
#
#
# -------
# Instr =  116 ( 8 )
#
#
#
#
# -------
# Instr =  117 ( 9 )
#
#
#
#
# -------
# Instr =  118 ( 10 )
#
#
#
#
# -------
# Instr =  119 ( 8 )
#
#
#
#
# -------
# Instr =  120 ( 9 )
#
#
#
#
# -------
# Instr =  121 ( 10 )
#
#
#
#
# -------
# Instr =  122 ( 8 )
#
#
#
#
# -------
# Instr =  123 ( 9 )
#
#
#
#
# -------
# Instr =  124 ( 10 )
#
#
#
#
# -------
# Instr =  125 ( 8 )
#
#
#
#
# -------
# Instr =  126 ( 9 )
#
#
#
#
# -------
# Instr =  127 ( 10 )
#
#
#
#
# -------
# Instr =  128 ( 8 )
#
#
#
#
# -------
# Instr =  129 ( 9 )
#
#
#
#
# -------
# Instr =  130 ( 10 )
#
#
#
#
# -------
# Instr =  131 ( 8 )
#
#
#
#
# -------
# Instr =  132 ( 9 )
#
#
#
#
# -------
# Instr =  133 ( 10 )
#
#
#
#
# -------
# Instr =  134 ( 8 )
#
#
#
#
# -------
# Instr =  135 ( 9 )
#
#
#
#
# -------
# Instr =  136 ( 10 )
#
#
#
#
# -------
# Instr =  137 ( 8 )
#
#
#
#
# -------
# Instr =  138 ( 9 )
#
#
#
#
# -------
# Instr =  139 ( 10 )
#
#
#
#
# -------
# Instr =  140 ( 8 )
#
#
#
#
# -------
# Instr =  141 ( 9 )
#
#
#
#
# -------
# Instr =  142 ( 10 )
#
#
#
#
# -------
# Instr =  143 ( 8 )
#
#
#
#
# -------
# Instr =  144 ( 9 )
#
#
#
#
# -------
# Instr =  145 ( 10 )
#
#
#
#
# -------
# Instr =  146 ( 8 )
#
#
#
#
# -------
# Instr =  147 ( 9 )
#
#
#
#
# -------
# Instr =  148 ( 10 )
#
#
#
#
# -------
# Instr =  149 ( 8 )
#
#
#
#
# -------
# Instr =  150 ( 9 )
#
#
#
#
# -------
# Instr =  151 ( 10 )
#
#
#
#
# -------
# Instr =  152 ( 8 )
#
#
#
#
# -------
# Instr =  153 ( 9 )
#
#
#
#
# -------
# Instr =  154 ( 10 )
#
#
#
#
# -------
# Instr =  155 ( 8 )
#
#
#
#
# -------
# Instr =  156 ( 9 )
#
#
#
#
# -------
# Instr =  157 ( 10 )
#
#
#
#
# -------
# Instr =  158 ( 8 )
#
#
#
#
# -------
# Instr =  159 ( 9 )
#
#
#
#
# -------
# Instr =  160 ( 10 )
#
#
#
#
# -------
# Instr =  161 ( 8 )
#
#
#
#
# -------
# Instr =  162 ( 9 )
#
#
#
#
# -------
# Instr =  163 ( 10 )
#
#
#
#
# -------
# Instr =  164 ( 8 )
#
#
#
#
# -------
# Instr =  165 ( 9 )
#
#
#
#
# -------
# Instr =  166 ( 10 )
#
#
#
#
# -------
# Instr =  167 ( 8 )
#
#
#
#
# -------
# Instr =  168 ( 9 )
#
#
#
#
# -------
# Instr =  169 ( 10 )
#
#
#
#
# -------
# Instr =  170 ( 8 )
#
#
#
#
# -------
# Instr =  171 ( 9 )
#
#
#
#
# -------
# Instr =  172 ( 10 )
#
#
#
#
# -------
# Instr =  173 ( 8 )
#
#
#
#
# -------
# Instr =  174 ( 9 )
#
#
#
#
# -------
# Instr =  175 ( 10 )
#
#
#
#
# -------
# Instr =  176 ( 8 )
#
#
#
#
# -------
# Instr =  177 ( 9 )
#
#
#
#
# -------
# Instr =  178 ( 10 )
#
#
#
#
# -------
# Instr =  179 ( 8 )
#
#
#
#
# -------
# Instr =  180 ( 9 )
#
#
#
#
# -------
# Instr =  181 ( 10 )
#
#
#
#
# -------
# Instr =  182 ( 8 )
#
#
#
#
# -------
# Instr =  183 ( 9 )
#
#
#
#
# -------
# Instr =  184 ( 10 )
#
#
#
#
# -------
# Instr =  185 ( 8 )
#
#
#
#
# -------
# Instr =  186 ( 9 )
#
#
#
#
# -------
# Instr =  187 ( 10 )
#
#
#
#
# -------
# Instr =  188 ( 8 )
#
#
#
#
# -------
# Instr =  189 ( 9 )
#
#
#
#
# -------
# Instr =  190 ( 10 )
#
#
#
#
# -------
# Instr =  191 ( 8 )
#
#
#
#
# -------
# Instr =  192 ( 9 )
#
#
#
#
# -------
# Instr =  193 ( 10 )
#
#
#
#
# -------
# Instr =  194 ( 8 )
#
#
#
#
# -------
# Instr =  195 ( 11 )
#
#
#
#
# -------
# Instr =  196 ( 12 )
#
#
#
#
# -------
# Instr =  197 ( 13 )
#
#
#
#
# -------
# Instr =  198 ( 14 )
#
#
#
#
# -------
# Instr =  199 ( 15 )
#
#
#
#
# -------
# Instr =  200 ( 16 )
#
#
#
#
# -------
# Instr =  201 ( 17 )
#
#
#
#
#
# Configuration time: 18 CC
# Time between end of configuration and start of first iteration: 68 CC
# Total time for all instructions: 596 CC
#
# Average power per operation:
#
# [5.33e-05, 8.59e-05, 1.05e-04, 5.54e-05]
# [2.31e-05, 4.41e-05, 8.37e-05, 5.33e-05]
# [5.31e-05, 5.36e-05, 6.11e-05, 1.19e-04]
# [6.12e-05, 7.42e-05, 6.96e-05, 5.49e-05]
#
# Power estimation for all instructions: 1.05e-03  W
#
# Total energy consumed during execution: 4.38e-09 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 325
# Number of missing reconfigurations:
# LWD-LWD: 5
# LWD-NOP: 4
# SMUL-SMUL: 64
# BEQ-LWI: 63
# LWI-LWI: 64
# SMUL-SWI: 63
# SADD-SWI: 63
# NOP-SWI: 2
# EXIT-NOP: 1
#
#
# END

# %%
import sys
sys.path.append("src/")
from cgra import *
# sha2
kernel_name = "examples/sha2"
version = ""
clear_memory(kernel_name, version)
add_memory_region(kernel_name, 100, [22698, 11480, -32658, -21981, -26949, -17398, -23942, 32423, -11483, 17581, 13842, -16291, 9355, -13496, 27455, 26106, 30664, -16369,
16471, -30316, -494, 32688, -11249, 967, 10429, 19344, 21117, -24938, -26203, -31221, 32568, 30046, 10410, -10212, -17320, -827, -28713, -27820, 3709, 8141], version)
add_memory_region(kernel_name, 36464, [1518500249], version)
load_addrs = [100, 36464,36464, 36464]
store_addrs = [128, 132, 136, 140]
memory_manager = MEMORY()
# run(kernel_name, version=version, pr=["OPS", "R0", "R2", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], load_addrs=load_addrs, store_addrs=store_addrs, limit=1000)
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)
# Out:
# [[100, 22698], [104, 11480], [108, -32658], [112, -21981], [116, -26949], [120, -17398], [124, -23942], [128, 32423], [132, -11483], [136, 17581], [140, 13842], [144, -16291], [148, 9355], [152, -13496], [156, 27455], [160, 26106], [164, 30664], [168, -16369], [172, 16471], [176, -30316], [180, -494], [184, 32688], [188, -11249], [192, 967], [196, 10429], [200, 19344], [204, 21117], [208, -24938], [212, -26203], [216, -31221], [220, 32568], [224, 30046], [228, 10410], [232, -10212], [236, -17320], [240, -827], [244, -28713], [248, -27820], [252, 3709], [256, 8141], [36464, 1518500249]]
# [100, 36464, 36464, 36464]
# [128, 132, 136, 140]
# Instr =  0 ( 0 )
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
#
#
#
#
# -------
# Instr =  1 ( 1 )
#
#
#
#
# -------
# Instr =  2 ( 2 )
#
#
#
#
# -------
# Instr =  3 ( 3 )
#
#
#
#
# -------
# Instr =  4 ( 4 )
#
#
#
#
# -------
# Instr =  5 ( 5 )
#
#
#
#
# -------
# Instr =  6 ( 6 )
#
#
#
#
# -------
# Instr =  7 ( 7 )
#
#
#
#
# -------
# Instr =  8 ( 8 )
#
#
#
#
# -------
# Instr =  9 ( 1 )
#
#
#
#
# -------
# Instr =  10 ( 2 )
#
#
#
#
# -------
# Instr =  11 ( 3 )
#
#
#
#
# -------
# Instr =  12 ( 4 )
#
#
#
#
# -------
# Instr =  13 ( 5 )
#
#
#
#
# -------
# Instr =  14 ( 6 )
#
#
#
#
# -------
# Instr =  15 ( 7 )
#
#
#
#
# -------
# Instr =  16 ( 8 )
#
#
#
#
# -------
# Instr =  17 ( 1 )
#
#
#
#
# -------
# Instr =  18 ( 2 )
#
#
#
#
# -------
# Instr =  19 ( 3 )
#
#
#
#
# -------
# Instr =  20 ( 4 )
#
#
#
#
# -------
# Instr =  21 ( 5 )
#
#
#
#
# -------
# Instr =  22 ( 6 )
#
#
#
#
# -------
# Instr =  23 ( 7 )
#
#
#
#
# -------
# Instr =  24 ( 8 )
#
#
#
#
# -------
# Instr =  25 ( 1 )
#
#
#
#
# -------
# Instr =  26 ( 2 )
#
#
#
#
# -------
# Instr =  27 ( 3 )
#
#
#
#
# -------
# Instr =  28 ( 4 )
#
#
#
#
# -------
# Instr =  29 ( 5 )
#
#
#
#
# -------
# Instr =  30 ( 6 )
#
#
#
#
# -------
# Instr =  31 ( 7 )
#
#
#
#
# -------
# Instr =  32 ( 8 )
#
#
#
#
# -------
# Instr =  33 ( 1 )
#
#
#
#
# -------
# Instr =  34 ( 2 )
#
#
#
#
# -------
# Instr =  35 ( 3 )
#
#
#
#
# -------
# Instr =  36 ( 4 )
#
#
#
#
# -------
# Instr =  37 ( 5 )
#
#
#
#
# -------
# Instr =  38 ( 6 )
#
#
#
#
# -------
# Instr =  39 ( 7 )
#
#
#
#
# -------
# Instr =  40 ( 8 )
#
#
#
#
# -------
# Instr =  41 ( 1 )
#
#
#
#
# -------
# Instr =  42 ( 2 )
#
#
#
#
# -------
# Instr =  43 ( 3 )
#
#
#
#
# -------
# Instr =  44 ( 4 )
#
#
#
#
# -------
# Instr =  45 ( 5 )
#
#
#
#
# -------
# Instr =  46 ( 6 )
#
#
#
#
# -------
# Instr =  47 ( 7 )
#
#
#
#
# -------
# Instr =  48 ( 8 )
#
#
#
#
# -------
# Instr =  49 ( 1 )
#
#
#
#
# -------
# Instr =  50 ( 2 )
#
#
#
#
# -------
# Instr =  51 ( 3 )
#
#
#
#
# -------
# Instr =  52 ( 4 )
#
#
#
#
# -------
# Instr =  53 ( 5 )
#
#
#
#
# -------
# Instr =  54 ( 6 )
#
#
#
#
# -------
# Instr =  55 ( 7 )
#
#
#
#
# -------
# Instr =  56 ( 8 )
#
#
#
#
# -------
# Instr =  57 ( 1 )
#
#
#
#
# -------
# Instr =  58 ( 2 )
#
#
#
#
# -------
# Instr =  59 ( 3 )
#
#
#
#
# -------
# Instr =  60 ( 4 )
#
#
#
#
# -------
# Instr =  61 ( 5 )
#
#
#
#
# -------
# Instr =  62 ( 6 )
#
#
#
#
# -------
# Instr =  63 ( 7 )
#
#
#
#
# -------
# Instr =  64 ( 8 )
#
#
#
#
# -------
# Instr =  65 ( 1 )
#
#
#
#
# -------
# Instr =  66 ( 2 )
#
#
#
#
# -------
# Instr =  67 ( 3 )
#
#
#
#
# -------
# Instr =  68 ( 4 )
#
#
#
#
# -------
# Instr =  69 ( 5 )
#
#
#
#
# -------
# Instr =  70 ( 6 )
#
#
#
#
# -------
# Instr =  71 ( 7 )
#
#
#
#
# -------
# Instr =  72 ( 8 )
#
#
#
#
# -------
# Instr =  73 ( 1 )
#
#
#
#
# -------
# Instr =  74 ( 2 )
#
#
#
#
# -------
# Instr =  75 ( 3 )
#
#
#
#
# -------
# Instr =  76 ( 4 )
#
#
#
#
# -------
# Instr =  77 ( 5 )
#
#
#
#
# -------
# Instr =  78 ( 6 )
#
#
#
#
# -------
# Instr =  79 ( 7 )
#
#
#
#
# -------
# Instr =  80 ( 8 )
#
#
#
#
# -------
# Instr =  81 ( 1 )
#
#
#
#
# -------
# Instr =  82 ( 2 )
#
#
#
#
# -------
# Instr =  83 ( 3 )
#
#
#
#
# -------
# Instr =  84 ( 4 )
#
#
#
#
# -------
# Instr =  85 ( 5 )
#
#
#
#
# -------
# Instr =  86 ( 6 )
#
#
#
#
# -------
# Instr =  87 ( 7 )
#
#
#
#
# -------
# Instr =  88 ( 8 )
#
#
#
#
# -------
# Instr =  89 ( 1 )
#
#
#
#
# -------
# Instr =  90 ( 2 )
#
#
#
#
# -------
# Instr =  91 ( 3 )
#
#
#
#
# -------
# Instr =  92 ( 4 )
#
#
#
#
# -------
# Instr =  93 ( 5 )
#
#
#
#
# -------
# Instr =  94 ( 6 )
#
#
#
#
# -------
# Instr =  95 ( 7 )
#
#
#
#
# -------
# Instr =  96 ( 8 )
#
#
#
#
# -------
# Instr =  97 ( 1 )
#
#
#
#
# -------
# Instr =  98 ( 2 )
#
#
#
#
# -------
# Instr =  99 ( 3 )
#
#
#
#
# -------
# Instr =  100 ( 4 )
#
#
#
#
# -------
# Instr =  101 ( 5 )
#
#
#
#
# -------
# Instr =  102 ( 6 )
#
#
#
#
# -------
# Instr =  103 ( 7 )
#
#
#
#
# -------
# Instr =  104 ( 8 )
#
#
#
#
# -------
# Instr =  105 ( 1 )
#
#
#
#
# -------
# Instr =  106 ( 2 )
#
#
#
#
# -------
# Instr =  107 ( 3 )
#
#
#
#
# -------
# Instr =  108 ( 4 )
#
#
#
#
# -------
# Instr =  109 ( 5 )
#
#
#
#
# -------
# Instr =  110 ( 6 )
#
#
#
#
# -------
# Instr =  111 ( 7 )
#
#
#
#
# -------
# Instr =  112 ( 8 )
#
#
#
#
# -------
# Instr =  113 ( 1 )
#
#
#
#
# -------
# Instr =  114 ( 2 )
#
#
#
#
# -------
# Instr =  115 ( 3 )
#
#
#
#
# -------
# Instr =  116 ( 4 )
#
#
#
#
# -------
# Instr =  117 ( 5 )
#
#
#
#
# -------
# Instr =  118 ( 6 )
#
#
#
#
# -------
# Instr =  119 ( 7 )
#
#
#
#
# -------
# Instr =  120 ( 8 )
#
#
#
#
# -------
# Instr =  121 ( 1 )
#
#
#
#
# -------
# Instr =  122 ( 2 )
#
#
#
#
# -------
# Instr =  123 ( 3 )
#
#
#
#
# -------
# Instr =  124 ( 4 )
#
#
#
#
# -------
# Instr =  125 ( 5 )
#
#
#
#
# -------
# Instr =  126 ( 6 )
#
#
#
#
# -------
# Instr =  127 ( 7 )
#
#
#
#
# -------
# Instr =  128 ( 8 )
#
#
#
#
# -------
# Instr =  129 ( 1 )
#
#
#
#
# -------
# Instr =  130 ( 2 )
#
#
#
#
# -------
# Instr =  131 ( 3 )
#
#
#
#
# -------
# Instr =  132 ( 4 )
#
#
#
#
# -------
# Instr =  133 ( 5 )
#
#
#
#
# -------
# Instr =  134 ( 6 )
#
#
#
#
# -------
# Instr =  135 ( 7 )
#
#
#
#
# -------
# Instr =  136 ( 8 )
#
#
#
#
# -------
# Instr =  137 ( 1 )
#
#
#
#
# -------
# Instr =  138 ( 2 )
#
#
#
#
# -------
# Instr =  139 ( 3 )
#
#
#
#
# -------
# Instr =  140 ( 4 )
#
#
#
#
# -------
# Instr =  141 ( 5 )
#
#
#
#
# -------
# Instr =  142 ( 6 )
#
#
#
#
# -------
# Instr =  143 ( 7 )
#
#
#
#
# -------
# Instr =  144 ( 8 )
#
#
#
#
# -------
# Instr =  145 ( 1 )
#
#
#
#
# -------
# Instr =  146 ( 2 )
#
#
#
#
# -------
# Instr =  147 ( 3 )
#
#
#
#
# -------
# Instr =  148 ( 4 )
#
#
#
#
# -------
# Instr =  149 ( 5 )
#
#
#
#
# -------
# Instr =  150 ( 6 )
#
#
#
#
# -------
# Instr =  151 ( 7 )
#
#
#
#
# -------
# Instr =  152 ( 8 )
#
#
#
#
# -------
# Instr =  153 ( 1 )
#
#
#
#
# -------
# Instr =  154 ( 2 )
#
#
#
#
# -------
# Instr =  155 ( 3 )
#
#
#
#
# -------
# Instr =  156 ( 4 )
#
#
#
#
# -------
# Instr =  157 ( 5 )
#
#
#
#
# -------
# Instr =  158 ( 6 )
#
#
#
#
# -------
# Instr =  159 ( 7 )
#
#
#
#
# -------
# Instr =  160 ( 8 )
#
#
#
#
# -------
# Instr =  161 ( 9 )
#
#
#
#
# -------
# Instr =  162 ( 10 )
#
#
#
#
#
# Configuration time: 11 CC
# Time between end of configuration and start of first iteration: 47 CC
# Total time for all instructions: 231 CC
#
# Average power per operation:
#
# [3.04e-05, 3.03e-05, 7.12e-05, 7.62e-05]
# [5.28e-05, 8.06e-05, 3.64e-05, 3.06e-05]
# [5.61e-05, 3.08e-05, 4.84e-05, 3.65e-05]
# [7.61e-05, 5.49e-05, 2.16e-05, 3.63e-05]
#
# Power estimation for all instructions: 7.69e-04  W
#
# Total energy consumed during execution: 1.31e-09 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 27
# Number of reconfigurations:
# NOP-NOP: 1701
# SADD-SADD: 28
# LWD-LWD: 2
# NOP-SADD: 444
# LWD-NOP: 2
# NOP-SRT: 60
# NOP-SLT: 40
# NOP-SMUL: 20
# LOR-NOP: 60
# LXOR-SMUL: 20
# LAND-NOP: 60
# LXOR-SADD: 20
# SLT-SRT: 20
# LAND-SADD: 20
# LWI-NOP: 40
# LOR-SLT: 20
# BNE-NOP: 40
# NOP-SWD: 9
# SADD-SWD: 1
# EXIT-NOP: 1
#
#
# END

# %%
# reversebits
import sys
sys.path.append("src/")
from cgra import *
kernel_name = "examples/reversebits"
version = ""
add_memory_region(kernel_name, 92, [-957294422, 32], version)
load_addrs = [92, 100,108, 112]
store_addrs = [128, 132, 136, 140]
memory_manager = MEMORY()
# run(kernel_name, version=version, pr=["OPS", "R0", "R2", "ALL_LAT_INFO", "ALL_PWR_EN_INFO"], load_addrs=load_addrs, store_addrs=store_addrs, limit=1000)
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)
# Out:
# [[92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32], [92, -957294422], [96, 32]]
# [92, 100, 108, 112]
# [128, 132, 136, 140]
# Instr =  0 ( 0 )
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
#
#
#
#
# -------
# Instr =  1 ( 1 )
#
#
#
#
# -------
# Instr =  2 ( 2 )
#
#
#
#
# -------
# Instr =  3 ( 3 )
#
#
#
#
# -------
# Instr =  4 ( 1 )
#
#
#
#
# -------
# Instr =  5 ( 2 )
#
#
#
#
# -------
# Instr =  6 ( 3 )
#
#
#
#
# -------
# Instr =  7 ( 1 )
#
#
#
#
# -------
# Instr =  8 ( 2 )
#
#
#
#
# -------
# Instr =  9 ( 3 )
#
#
#
#
# -------
# Instr =  10 ( 1 )
#
#
#
#
# -------
# Instr =  11 ( 2 )
#
#
#
#
# -------
# Instr =  12 ( 3 )
#
#
#
#
# -------
# Instr =  13 ( 1 )
#
#
#
#
# -------
# Instr =  14 ( 2 )
#
#
#
#
# -------
# Instr =  15 ( 3 )
#
#
#
#
# -------
# Instr =  16 ( 1 )
#
#
#
#
# -------
# Instr =  17 ( 2 )
#
#
#
#
# -------
# Instr =  18 ( 3 )
#
#
#
#
# -------
# Instr =  19 ( 1 )
#
#
#
#
# -------
# Instr =  20 ( 2 )
#
#
#
#
# -------
# Instr =  21 ( 3 )
#
#
#
#
# -------
# Instr =  22 ( 1 )
#
#
#
#
# -------
# Instr =  23 ( 2 )
#
#
#
#
# -------
# Instr =  24 ( 3 )
#
#
#
#
# -------
# Instr =  25 ( 1 )
#
#
#
#
# -------
# Instr =  26 ( 2 )
#
#
#
#
# -------
# Instr =  27 ( 3 )
#
#
#
#
# -------
# Instr =  28 ( 1 )
#
#
#
#
# -------
# Instr =  29 ( 2 )
#
#
#
#
# -------
# Instr =  30 ( 3 )
#
#
#
#
# -------
# Instr =  31 ( 1 )
#
#
#
#
# -------
# Instr =  32 ( 2 )
#
#
#
#
# -------
# Instr =  33 ( 3 )
#
#
#
#
# -------
# Instr =  34 ( 1 )
#
#
#
#
# -------
# Instr =  35 ( 2 )
#
#
#
#
# -------
# Instr =  36 ( 3 )
#
#
#
#
# -------
# Instr =  37 ( 1 )
#
#
#
#
# -------
# Instr =  38 ( 2 )
#
#
#
#
# -------
# Instr =  39 ( 3 )
#
#
#
#
# -------
# Instr =  40 ( 1 )
#
#
#
#
# -------
# Instr =  41 ( 2 )
#
#
#
#
# -------
# Instr =  42 ( 3 )
#
#
#
#
# -------
# Instr =  43 ( 1 )
#
#
#
#
# -------
# Instr =  44 ( 2 )
#
#
#
#
# -------
# Instr =  45 ( 3 )
#
#
#
#
# -------
# Instr =  46 ( 1 )
#
#
#
#
# -------
# Instr =  47 ( 2 )
#
#
#
#
# -------
# Instr =  48 ( 3 )
#
#
#
#
# -------
# Instr =  49 ( 1 )
#
#
#
#
# -------
# Instr =  50 ( 2 )
#
#
#
#
# -------
# Instr =  51 ( 3 )
#
#
#
#
# -------
# Instr =  52 ( 1 )
#
#
#
#
# -------
# Instr =  53 ( 2 )
#
#
#
#
# -------
# Instr =  54 ( 3 )
#
#
#
#
# -------
# Instr =  55 ( 1 )
#
#
#
#
# -------
# Instr =  56 ( 2 )
#
#
#
#
# -------
# Instr =  57 ( 3 )
#
#
#
#
# -------
# Instr =  58 ( 1 )
#
#
#
#
# -------
# Instr =  59 ( 2 )
#
#
#
#
# -------
# Instr =  60 ( 3 )
#
#
#
#
# -------
# Instr =  61 ( 1 )
#
#
#
#
# -------
# Instr =  62 ( 2 )
#
#
#
#
# -------
# Instr =  63 ( 3 )
#
#
#
#
# -------
# Instr =  64 ( 1 )
#
#
#
#
# -------
# Instr =  65 ( 2 )
#
#
#
#
# -------
# Instr =  66 ( 3 )
#
#
#
#
# -------
# Instr =  67 ( 1 )
#
#
#
#
# -------
# Instr =  68 ( 2 )
#
#
#
#
# -------
# Instr =  69 ( 3 )
#
#
#
#
# -------
# Instr =  70 ( 1 )
#
#
#
#
# -------
# Instr =  71 ( 2 )
#
#
#
#
# -------
# Instr =  72 ( 3 )
#
#
#
#
# -------
# Instr =  73 ( 1 )
#
#
#
#
# -------
# Instr =  74 ( 2 )
#
#
#
#
# -------
# Instr =  75 ( 3 )
#
#
#
#
# -------
# Instr =  76 ( 1 )
#
#
#
#
# -------
# Instr =  77 ( 2 )
#
#
#
#
# -------
# Instr =  78 ( 3 )
#
#
#
#
# -------
# Instr =  79 ( 1 )
#
#
#
#
# -------
# Instr =  80 ( 2 )
#
#
#
#
# -------
# Instr =  81 ( 3 )
#
#
#
#
# -------
# Instr =  82 ( 1 )
#
#
#
#
# -------
# Instr =  83 ( 2 )
#
#
#
#
# -------
# Instr =  84 ( 3 )
#
#
#
#
# -------
# Instr =  85 ( 1 )
#
#
#
#
# -------
# Instr =  86 ( 2 )
#
#
#
#
# -------
# Instr =  87 ( 3 )
#
#
#
#
# -------
# Instr =  88 ( 1 )
#
#
#
#
# -------
# Instr =  89 ( 2 )
#
#
#
#
# -------
# Instr =  90 ( 3 )
#
#
#
#
# -------
# Instr =  91 ( 1 )
#
#
#
#
# -------
# Instr =  92 ( 2 )
#
#
#
#
# -------
# Instr =  93 ( 3 )
#
#
#
#
# -------
# Instr =  94 ( 1 )
#
#
#
#
# -------
# Instr =  95 ( 2 )
#
#
#
#
# -------
# Instr =  96 ( 3 )
#
#
#
#
# -------
# Instr =  97 ( 4 )
#
#
#
#
# -------
# Instr =  98 ( 5 )
#
#
#
#
#
# Configuration time: 6 CC
# Time between end of configuration and start of first iteration: 32 CC
# Total time for all instructions: 103 CC
#
# Average power per operation:
#
# [4.61e-05, 2.39e-05, 1.12e-04, 8.20e-05]
# [1.24e-04, 2.39e-05, 2.39e-05, 2.39e-05]
# [2.39e-05, 2.39e-05, 2.39e-05, 2.39e-05]
# [8.20e-05, 2.39e-05, 4.61e-05, 5.30e-05]
#
# Power estimation for all instructions: 7.60e-04  W
#
# Total energy consumed during execution: 5.31e-10 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 3
# Number of reconfigurations:
# NOP-NOP: 1063
# SADD-SADD: 35
# LWD-LWD: 2
# NOP-SADD: 192
# LWD-NOP: 2
# NOP-SLT: 32
# LAND-NOP: 64
# LOR-SLT: 32
# NOP-SRT: 64
# BLT-NOP: 64
# LOR-NOP: 31
# LOR-SWD: 1
# EXIT-NOP: 1
# NOP-SWD: 1
#
#
# END

# %%
# gsm
import sys
sys.path.append("src/")
from cgra import *
kernel_name = "examples/gsm"
version = "_v1"
clear_memory(kernel_name, version)
add_memory_region(kernel_name, 100, [22698, 11480, -32658, -21981, -26949, -17398, -23942, 32423, -11483, 17581, 13842, -16291, 9355, -13496, 27455, 26106, 30664, -16369,
16471, -30316, -494, 32688, -11249, 967, 10429, 19344, 21117, -24938, -26203, -31221, 32568, 30046, 10410, -10212, -17320, -827, -28713, -27820, 3709, 8141], version)
add_memory_region(kernel_name, 36464, [32767, -32768], version)
load_addrs = [92, 100,108, 36464]
store_addrs = [56, 68, 80, 92]


add_memory_region(kernel_name, 8, [8, 1, 2], version)
add_memory_region(kernel_name, 20, [8, 3, 4], version)
add_memory_region(kernel_name, 32, [8, 5, 6], version)
add_memory_region(kernel_name, 44, [8, 7, 8], version)
# Set load and write addrs
load_addrs = [8, 20,32, 44]
# store_addrs = [56, 68, 80, 92]
store_addrs = [80, 92, 104, 116]
memory_manager = MEMORY()
# Run the example
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)
# Out:
# [[100, 22698], [104, 11480], [108, -32658], [112, -21981], [116, -26949], [120, -17398], [124, -23942], [128, 32423], [132, -11483], [136, 17581], [140, 13842], [144, -16291], [148, 9355], [152, -13496], [156, 27455], [160, 26106], [164, 30664], [168, -16369], [172, 16471], [176, -30316], [180, -494], [184, 32688], [188, -11249], [192, 967], [196, 10429], [200, 19344], [204, 21117], [208, -24938], [212, -26203], [216, -31221], [220, 32568], [224, 30046], [228, 10410], [232, -10212], [236, -17320], [240, -827], [244, -28713], [248, -27820], [252, 3709], [256, 8141], [36464, 32767], [36468, -32768], [8, 8], [12, 1], [16, 2], [20, 8], [24, 3], [28, 4], [32, 8], [36, 5], [40, 6], [44, 8], [48, 7], [52, 8]]
# [8, 20, 32, 44]
# [80, 92, 104, 116]
# Instr =  0 ( 0 )
# 2.75e-05
# 3.32e-05
# 2.75e-05
# 3.32e-05
# 2.75e-05
# 3.32e-05
#
#
#
#
# -------
# Instr =  1 ( 1 )
#
#
#
#
# -------
# Instr =  2 ( 2 )
#
#
#
#
# -------
# Instr =  3 ( 3 )
#
#
#
#
# -------
# Instr =  4 ( 4 )
#
#
#
#
# -------
# Instr =  5 ( 5 )
#
#
#
#
# -------
# Instr =  6 ( 6 )
#
#
#
#
# -------
# Instr =  7 ( 7 )
#
#
#
#
# -------
# Instr =  8 ( 8 )
#
#
#
#
# -------
# Instr =  9 ( 9 )
#
#
#
#
# -------
# Instr =  10 ( 10 )
#
#
#
#
# -------
# Instr =  11 ( 11 )
#
#
#
#
# -------
# Instr =  12 ( 12 )
#
#
#
#
# -------
# Instr =  13 ( 9 )
#
#
#
#
# -------
# Instr =  14 ( 10 )
#
#
#
#
# -------
# Instr =  15 ( 11 )
#
#
#
#
# -------
# Instr =  16 ( 12 )
#
#
#
#
# -------
# Instr =  17 ( 9 )
#
#
#
#
# -------
# Instr =  18 ( 10 )
#
#
#
#
# -------
# Instr =  19 ( 11 )
#
#
#
#
# -------
# Instr =  20 ( 12 )
#
#
#
#
# -------
# Instr =  21 ( 9 )
#
#
#
#
# -------
# Instr =  22 ( 10 )
#
#
#
#
# -------
# Instr =  23 ( 11 )
#
#
#
#
# -------
# Instr =  24 ( 12 )
#
#
#
#
# -------
# Instr =  25 ( 9 )
#
#
#
#
# -------
# Instr =  26 ( 10 )
#
#
#
#
# -------
# Instr =  27 ( 11 )
#
#
#
#
# -------
# Instr =  28 ( 12 )
#
#
#
#
# -------
# Instr =  29 ( 9 )
#
#
#
#
# -------
# Instr =  30 ( 10 )
#
#
#
#
# -------
# Instr =  31 ( 11 )
#
#
#
#
# -------
# Instr =  32 ( 12 )
#
#
#
#
# -------
# Instr =  33 ( 9 )
#
#
#
#
# -------
# Instr =  34 ( 10 )
#
#
#
#
# -------
# Instr =  35 ( 11 )
#
#
#
#
# -------
# Instr =  36 ( 12 )
#
#
#
#
# -------
# Instr =  37 ( 9 )
#
#
#
#
# -------
# Instr =  38 ( 10 )
#
#
#
#
# -------
# Instr =  39 ( 11 )
#
#
#
#
# -------
# Instr =  40 ( 12 )
#
#
#
#
# -------
# Instr =  41 ( 9 )
#
#
#
#
# -------
# Instr =  42 ( 10 )
#
#
#
#
# -------
# Instr =  43 ( 11 )
#
#
#
#
# -------
# Instr =  44 ( 12 )
#
#
#
#
# -------
# Instr =  45 ( 9 )
#
#
#
#
# -------
# Instr =  46 ( 10 )
#
#
#
#
# -------
# Instr =  47 ( 11 )
#
#
#
#
# -------
# Instr =  48 ( 12 )
#
#
#
#
# -------
# Instr =  49 ( 9 )
#
#
#
#
# -------
# Instr =  50 ( 10 )
#
#
#
#
# -------
# Instr =  51 ( 11 )
#
#
#
#
# -------
# Instr =  52 ( 12 )
#
#
#
#
# -------
# Instr =  53 ( 9 )
#
#
#
#
# -------
# Instr =  54 ( 10 )
#
#
#
#
# -------
# Instr =  55 ( 11 )
#
#
#
#
# -------
# Instr =  56 ( 12 )
#
#
#
#
# -------
# Instr =  57 ( 9 )
#
#
#
#
# -------
# Instr =  58 ( 10 )
#
#
#
#
# -------
# Instr =  59 ( 11 )
#
#
#
#
# -------
# Instr =  60 ( 12 )
#
#
#
#
# -------
# Instr =  61 ( 9 )
#
#
#
#
# -------
# Instr =  62 ( 10 )
#
#
#
#
# -------
# Instr =  63 ( 11 )
#
#
#
#
# -------
# Instr =  64 ( 12 )
#
#
#
#
# -------
# Instr =  65 ( 9 )
#
#
#
#
# -------
# Instr =  66 ( 10 )
#
#
#
#
# -------
# Instr =  67 ( 11 )
#
#
#
#
# -------
# Instr =  68 ( 12 )
#
#
#
#
# -------
# Instr =  69 ( 9 )
#
#
#
#
# -------
# Instr =  70 ( 10 )
#
#
#
#
# -------
# Instr =  71 ( 11 )
#
#
#
#
# -------
# Instr =  72 ( 12 )
#
#
#
#
# -------
# Instr =  73 ( 9 )
#
#
#
#
# -------
# Instr =  74 ( 10 )
#
#
#
#
# -------
# Instr =  75 ( 11 )
#
#
#
#
# -------
# Instr =  76 ( 12 )
#
#
#
#
# -------
# Instr =  77 ( 9 )
#
#
#
#
# -------
# Instr =  78 ( 10 )
#
#
#
#
# -------
# Instr =  79 ( 11 )
#
#
#
#
# -------
# Instr =  80 ( 12 )
#
#
#
#
# -------
# Instr =  81 ( 9 )
#
#
#
#
# -------
# Instr =  82 ( 10 )
#
#
#
#
# -------
# Instr =  83 ( 11 )
#
#
#
#
# -------
# Instr =  84 ( 12 )
#
#
#
#
# -------
# Instr =  85 ( 9 )
#
#
#
#
# -------
# Instr =  86 ( 10 )
#
#
#
#
# -------
# Instr =  87 ( 11 )
#
#
#
#
# -------
# Instr =  88 ( 12 )
#
#
#
#
# -------
# Instr =  89 ( 9 )
#
#
#
#
# -------
# Instr =  90 ( 10 )
#
#
#
#
# -------
# Instr =  91 ( 11 )
#
#
#
#
# -------
# Instr =  92 ( 12 )
#
#
#
#
# -------
# Instr =  93 ( 9 )
#
#
#
#
# -------
# Instr =  94 ( 10 )
#
#
#
#
# -------
# Instr =  95 ( 11 )
#
#
#
#
# -------
# Instr =  96 ( 12 )
#
#
#
#
# -------
# Instr =  97 ( 9 )
#
#
#
#
# -------
# Instr =  98 ( 10 )
#
#
#
#
# -------
# Instr =  99 ( 11 )
#
#
#
#
# -------
# Instr =  100 ( 12 )
#
#
#
#
# -------
# Instr =  101 ( 9 )
#
#
#
#
# -------
# Instr =  102 ( 10 )
#
#
#
#
# -------
# Instr =  103 ( 11 )
#
#
#
#
# -------
# Instr =  104 ( 12 )
#
#
#
#
# -------
# Instr =  105 ( 9 )
#
#
#
#
# -------
# Instr =  106 ( 10 )
#
#
#
#
# -------
# Instr =  107 ( 11 )
#
#
#
#
# -------
# Instr =  108 ( 12 )
#
#
#
#
# -------
# Instr =  109 ( 9 )
#
#
#
#
# -------
# Instr =  110 ( 10 )
#
#
#
#
# -------
# Instr =  111 ( 11 )
#
#
#
#
# -------
# Instr =  112 ( 12 )
#
#
#
#
# -------
# Instr =  113 ( 9 )
#
#
#
#
# -------
# Instr =  114 ( 10 )
#
#
#
#
# -------
# Instr =  115 ( 11 )
#
#
#
#
# -------
# Instr =  116 ( 12 )
#
#
#
#
# -------
# Instr =  117 ( 9 )
#
#
#
#
# -------
# Instr =  118 ( 10 )
#
#
#
#
# -------
# Instr =  119 ( 11 )
#
#
#
#
# -------
# Instr =  120 ( 12 )
#
#
#
#
# -------
# Instr =  121 ( 9 )
#
#
#
#
# -------
# Instr =  122 ( 10 )
#
#
#
#
# -------
# Instr =  123 ( 11 )
#
#
#
#
# -------
# Instr =  124 ( 12 )
#
#
#
#
# -------
# Instr =  125 ( 9 )
#
#
#
#
# -------
# Instr =  126 ( 10 )
#
#
#
#
# -------
# Instr =  127 ( 11 )
#
#
#
#
# -------
# Instr =  128 ( 12 )
#
#
#
#
# -------
# Instr =  129 ( 9 )
#
#
#
#
# -------
# Instr =  130 ( 10 )
#
#
#
#
# -------
# Instr =  131 ( 11 )
#
#
#
#
# -------
# Instr =  132 ( 12 )
#
#
#
#
# -------
# Instr =  133 ( 9 )
#
#
#
#
# -------
# Instr =  134 ( 10 )
#
#
#
#
# -------
# Instr =  135 ( 11 )
#
#
#
#
# -------
# Instr =  136 ( 12 )
#
#
#
#
# -------
# Instr =  137 ( 9 )
#
#
#
#
# -------
# Instr =  138 ( 10 )
#
#
#
#
# -------
# Instr =  139 ( 11 )
#
#
#
#
# -------
# Instr =  140 ( 12 )
#
#
#
#
# -------
# Instr =  141 ( 9 )
#
#
#
#
# -------
# Instr =  142 ( 10 )
#
#
#
#
# -------
# Instr =  143 ( 11 )
#
#
#
#
# -------
# Instr =  144 ( 12 )
#
#
#
#
# -------
# Instr =  145 ( 9 )
#
#
#
#
# -------
# Instr =  146 ( 10 )
#
#
#
#
# -------
# Instr =  147 ( 11 )
#
#
#
#
# -------
# Instr =  148 ( 12 )
#
#
#
#
# -------
# Instr =  149 ( 9 )
#
#
#
#
# -------
# Instr =  150 ( 10 )
#
#
#
#
# -------
# Instr =  151 ( 11 )
#
#
#
#
# -------
# Instr =  152 ( 12 )
#
#
#
#
# -------
# Instr =  153 ( 9 )
#
#
#
#
# -------
# Instr =  154 ( 10 )
#
#
#
#
# -------
# Instr =  155 ( 11 )
#
#
#
#
# -------
# Instr =  156 ( 12 )
#
#
#
#
# -------
# Instr =  157 ( 9 )
#
#
#
#
# -------
# Instr =  158 ( 10 )
#
#
#
#
# -------
# Instr =  159 ( 11 )
#
#
#
#
# -------
# Instr =  160 ( 12 )
#
#
#
#
# -------
# Instr =  161 ( 13 )
#
#
#
#
# -------
# Instr =  162 ( 14 )
#
#
#
#
# -------
# Instr =  163 ( 15 )
#
#
#
#
# -------
# Instr =  164 ( 16 )
#
#
#
#
# -------
# Instr =  165 ( 17 )
#
#
#
#
# -------
# Instr =  166 ( 18 )
#
#
#
#
# -------
# Instr =  167 ( 19 )
#
#
#
#
#
# Configuration time: 20 CC
# Time between end of configuration and start of first iteration: 74 CC
# Total time for all instructions: 293 CC
#
# Average power per operation:
#
# [4.41e-05, 2.01e-05, 3.46e-05, 6.41e-05]
# [6.48e-05, 2.01e-05, 2.01e-05, 2.01e-05]
# [4.34e-05, 2.01e-05, 2.01e-05, 8.00e-05]
# [3.43e-05, 8.27e-05, 5.69e-05, 1.10e-04]
#
# Power estimation for all instructions: 7.35e-04  W
#
# Total energy consumed during execution: 1.60e-09 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 44
# Number of reconfigurations:
# SADD-SADD: 4
# NOP-NOP: 1712
# LWD-LWD: 3
# NOP-SADD: 284
# LWD-NOP: 3
# NOP-SMUL: 40
# SADD-SMUL: 40
# BEQ-NOP: 4
# LWI-NOP: 80
# NOP-SSUB: 160
# BZFA-NOP: 80
# SADD-SSUB: 40
# BSFA-SADD: 40
# BSFA-NOP: 79
# BSFA-SSUB: 40
# BNE-NOP: 76
# BSFA-SWD: 1
# EXIT-NOP: 1
# NOP-SWD: 1
#
#
# END

# %%
import sys
sys.path.append("src/")
from cgra import *
kernel_name = "examples/practice"
version = ""
clear_memory(kernel_name, version)
add_memory_region(kernel_name, 8, [8, 1, 2], version)
add_memory_region(kernel_name, 20, [8, 3, 4], version)
add_memory_region(kernel_name, 32, [8, 5, 6], version)
add_memory_region(kernel_name, 44, [8, 7, 8], version)
# Set load and write addrs
load_addrs = [8, 20,32, 44]
store_addrs = [80, 92, 104, 116]
memory_manager = MEMORY()
# Run the example
run(kernel_name, version=version, pr=["FINAL_EN_INFO", "TOTAL_LAT"], memory_manager=memory_manager, load_addrs=load_addrs, store_addrs=store_addrs, limit=2000)
# Out:
# [[8, 8], [12, 1], [16, 2], [20, 8], [24, 3], [28, 4], [32, 8], [36, 5], [40, 6], [44, 8], [48, 7], [52, 8]]
# [8, 20, 32, 44]
# [80, 92, 104, 116]
# Instr =  0 ( 0 )
# 3.32e-05
# 3.32e-05
#
#
#
#
# -------
# Instr =  1 ( 1 )
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
#
#
#
#
# -------
# Instr =  2 ( 2 )
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
# 3.32e-05
#
#
#
#
# -------
# Instr =  3 ( 3 )
#
#
#
#
#
# Configuration time: 4 CC
# Time between end of configuration and start of first iteration: 26 CC
# Total time for all instructions: 16 CC
#
# Average power per operation:
#
# [3.22e-05, 2.69e-05, 2.16e-05, 2.16e-05]
# [3.02e-05, 2.69e-05, 2.16e-05, 2.16e-05]
# [2.69e-05, 2.69e-05, 2.16e-05, 2.16e-05]
# [2.69e-05, 2.69e-05, 2.16e-05, 2.16e-05]
#
# Power estimation for all instructions: 3.97e-04  W
#
# Total energy consumed during execution: -2.62e-11 J
#
# Clock period used: 1e-08 s
# Total number of memory accesses: 11
# Number of reconfigurations:
# LWD-LWD: 4
# NOP-NOP: 44
# LWD-NOP: 15
# EXIT-NOP: 1
#
#
# END
